# %% [markdown]
# # With Own Dataset

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error

# %%
# Load the dataset
df = pd.read_csv("realistic_salary_dataset.csv")

# %%
df.head()
# Out:
#             City    Education    Industry  YearsExperience Certification  \
# 0  San Francisco  High School  Healthcare               18           AWS
# 1         Austin      Masters      Retail               29           NaN
# 2        Chicago          PhD  Technology                5           NaN
# 3         Austin    Bachelors     Finance                1  Scrum Master
# 4         Austin  High School   Education               11           PMP
#
#    Salary
# 0   53753
# 1   77380
# 2   65670
# 3   33650
# 4   47668

# %%
x = df.drop(columns=['Salary'])
y = df['Salary']

# %%
# Encode categorical features using LabelEncoder
le = LabelEncoder()
for col in x.columns:
    if x[col].dtype == 'object':
        x[col + '_Encoded'] = le.fit_transform(x[col])

# %%
# Drop original categorical columns (keep only encoded ones and numeric)
x = x.select_dtypes(exclude='object')

# %%
x
# Out:
#      YearsExperience  City_Encoded  Education_Encoded  Industry_Encoded  \
# 0                 18             4                  1                 2
# 1                 29             0                  2                 3
# 2                  5             1                  3                 4
# 3                  1             0                  0                 1
# 4                 11             0                  1                 0
# ..               ...           ...                ...               ...
# 463               27             2                  0                 2
# 464                5             2                  1                 1
# 465               14             2                  2                 3
# 466                1             2                  1                 0
# 467               28             1                  0                 0
#
#      Certification_Encoded
# 0                        0
# 1                        4
# 2                        4
# 3                        3
# 4                        2
# ..                     ...
# 463                      4
# 464                      3
# 465                      0
# 466                      4
# 467                      4
#
# [468 rows x 5 columns]

# %%
# Split the data into training and test sets
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# %%
print(f"R² Score: {r2:.2f}")
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# R² Score: 0.83
# Mean Absolute Error: 5652.39

# %%
print(f'Coefficients: {model.coef_}')
print(f"Intercept: {model.intercept_}")
# Out:
# Coefficients: [1492.78932122  411.31127513 7077.01153006  742.06614526  -53.47219398]
# Intercept: 27471.247862209282
